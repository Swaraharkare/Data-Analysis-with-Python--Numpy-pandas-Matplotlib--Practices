# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("sample.txt",index_col='Car_Model')
# Convert to Series
series = df['Price_USD']
print(type(series))
print(series)
# Out:
# <class 'pandas.core.series.Series'>
# Car_Model
# Toyota Camry             26420
# Honda Civic              23950
# Ford Mustang             30920
# Tesla Model 3            38990
# Chevrolet Corvette       68300
# BMW M3                   76000
# Audi A4                  41900
# Mercedes-Benz C-Class    46950
# Hyundai Elantra          21475
# Nissan Altima            25730
# Name: Price_USD, dtype: int64

# %%
df = pd.read_csv("movies.txt",index_col='Movie_Title')
# Convert to Series
movies = df['Lead_Actor']
print(type(movies))
print(movies)
# Out:
# <class 'pandas.core.series.Series'>
# Movie_Title
# Avengers: Doomsday                               Robert Downey Jr.
# Oppenheimer                                      Robert Downey Jr.
# Sherlock Holmes 3                                Robert Downey Jr.
# Mission: Impossible - Dead Reckoning                    Tom Cruise
# Top Gun: Maverick                                       Tom Cruise
# Edge of Tomorrow                                        Tom Cruise
# Barbie                                               Margot Robbie
# A Big Bold Beautiful Journey                         Margot Robbie
# Suicide Squad                                        Margot Robbie
# Dune: Part Two                                             Zendaya
# Challengers                                                Zendaya
# Spider-Man: No Way Home                             Isabela Merced
# The Fall Guy                                          Ryan Gosling
# ...

# %%
#astype
import sys
sys.getsizeof(series)
# Out:
# 730

# %%
series.astype('int16')
sys.getsizeof(series)
# Out:
# 1030

# %%
#between
series[series.between(35000,60000)]
# Out:
# Car_Model
# Tesla Model 3            38990
# Audi A4                  41900
# Mercedes-Benz C-Class    46950
# Name: Price_USD, dtype: int64

# %%
series[series.between(35000,60000)].size
# Out:
# 3

# %%
#clip----we want to get value between 35k and 60k ...so all values which are less than 35k are replaced by 35k 
#and all values greter than 60k replaced by 60k
series.clip(35000,60000)
# Out:
# Car_Model
# Toyota Camry             35000
# Honda Civic              35000
# Ford Mustang             35000
# Tesla Model 3            38990
# Chevrolet Corvette       60000
# BMW M3                   60000
# Audi A4                  41900
# Mercedes-Benz C-Class    46950
# Hyundai Elantra          35000
# Nissan Altima            35000
# Name: Price_USD, dtype: int64

# %%
#drop_duplicates
temp=pd.Series([1,2,3,4,3,5,1,56,4,2,1,4,5])
temp
# Out:
# 0      1
# 1      2
# 2      3
# 3      4
# 4      3
# 5      5
# 6      1
# 7     56
# 8      4
# 9      2
# 10     1
# 11     4
# 12     5
# dtype: int64

# %%
temp.drop_duplicates()
# Out:
# 0     1
# 1     2
# 2     3
# 3     4
# 5     5
# 7    56
# dtype: int64

# %%
#to keep last value
temp.drop_duplicates(keep='last')
# Out:
# 4      3
# 7     56
# 9      2
# 10     1
# 11     4
# 12     5
# dtype: int64

# %%
movies.drop_duplicates()
# Out:
# Movie_Title
# Avengers: Doomsday                          Robert Downey Jr.
# Mission: Impossible - Dead Reckoning               Tom Cruise
# Barbie                                          Margot Robbie
# Dune: Part Two                                        Zendaya
# Spider-Man: No Way Home                        Isabela Merced
# The Fall Guy                                     Ryan Gosling
# Gladiator II                                      Paul Mescal
# Black Widow                                Scarlett Johansson
# Superman                                      David Corenswet
# Mardaani 3                                       Rani Mukerji
# The Bluff                               Priyanka Chopra Jonas
# War Machine                                     Alan Ritchson
# Crime 101                                     Chris Hemsworth
# Ballerina                                        Ana de Armas
# The Rip                                            Matt Damon
# ...

# %%
movies.duplicated().sum()
# Out:
# np.int64(16)

# %%
temp1=pd.Series([1,2,3,np.nan,4,5,np.nan,6,np.nan,8,9,np.nan])
temp1
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     4.0
# 5     5.0
# 6     NaN
# 7     6.0
# 8     NaN
# 9     8.0
# 10    9.0
# 11    NaN
# dtype: float64

# %%
#show size of series
print(temp1.size)

#show count of not null values
print(temp1.count())
# Out:
# 12
# 8

# %%
#isnull()---how much values are missing 
temp1.isnull().sum()
# Out:
# np.int64(4)

# %%
#dropna()
temp1.dropna()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     4.0
# 5     5.0
# 7     6.0
# 9     8.0
# 10    9.0
# dtype: float64

# %%
#fillna()
temp1.fillna(0)
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     0.0
# 4     4.0
# 5     5.0
# 6     0.0
# 7     6.0
# 8     0.0
# 9     8.0
# 10    9.0
# 11    0.0
# dtype: float64

# %%
temp1.fillna(temp1.mean())
# Out:
# 0     1.00
# 1     2.00
# 2     3.00
# 3     4.75
# 4     4.00
# 5     5.00
# 6     4.75
# 7     6.00
# 8     4.75
# 9     8.00
# 10    9.00
# 11    4.75
# dtype: float64

# %%
#isin
series[(series==21475) | (series==76000)]
# Out:
# Car_Model
# BMW M3             76000
# Hyundai Elantra    21475
# Name: Price_USD, dtype: int64

# %%
series[series.isin([21475,76000,41900])]
# Out:
# Car_Model
# BMW M3             76000
# Audi A4            41900
# Hyundai Elantra    21475
# Name: Price_USD, dtype: int64

# %%
#apply()
movies.apply(lambda x: x.split()[0].upper())
# Out:
# Movie_Title
# Avengers: Doomsday                             ROBERT
# Oppenheimer                                    ROBERT
# Sherlock Holmes 3                              ROBERT
# Mission: Impossible - Dead Reckoning              TOM
# Top Gun: Maverick                                 TOM
# Edge of Tomorrow                                  TOM
# Barbie                                         MARGOT
# A Big Bold Beautiful Journey                   MARGOT
# Suicide Squad                                  MARGOT
# Dune: Part Two                                ZENDAYA
# Challengers                                   ZENDAYA
# Spider-Man: No Way Home                       ISABELA
# The Fall Guy                                     RYAN
# La La Land                                       RYAN
# Project Hail Mary                                RYAN
# Gladiator II                                     PAUL
# Aftersun                                         PAUL
# ...

# %%
#apply
series.apply(lambda x:'Good Day' if x>series.mean() else 'Bad Day')
# Out:
# Car_Model
# Toyota Camry              Bad Day
# Honda Civic               Bad Day
# Ford Mustang              Bad Day
# Tesla Model 3             Bad Day
# Chevrolet Corvette       Good Day
# BMW M3                   Good Day
# Audi A4                  Good Day
# Mercedes-Benz C-Class    Good Day
# Hyundai Elantra           Bad Day
# Nissan Altima             Bad Day
# Name: Price_USD, dtype: object

# %%
#copy
series.copy()
# Out:
# Car_Model
# Toyota Camry             26420
# Honda Civic              23950
# Ford Mustang             30920
# Tesla Model 3            38990
# Chevrolet Corvette       68300
# BMW M3                   76000
# Audi A4                  41900
# Mercedes-Benz C-Class    46950
# Hyundai Elantra          21475
# Nissan Altima            25730
# Name: Price_USD, dtype: int64
