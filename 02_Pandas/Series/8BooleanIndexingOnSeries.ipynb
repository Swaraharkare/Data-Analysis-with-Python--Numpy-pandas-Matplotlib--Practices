# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("sample.txt",index_col='Car_Model')
# Convert to Series
series = df['Price_USD']
print(type(series))
print(series)
# Out:
# <class 'pandas.core.series.Series'>
# Car_Model
# Toyota Camry             26420
# Honda Civic              23950
# Ford Mustang             30920
# Tesla Model 3            38990
# Chevrolet Corvette       68300
# BMW M3                   76000
# Audi A4                  41900
# Mercedes-Benz C-Class    46950
# Hyundai Elantra          21475
# Nissan Altima            25730
# Name: Price_USD, dtype: int64

# %%
#find the price of car which is less than 35k 
series[series< 30000] # series[] shows only data of series where value is TRUE
series[series< 30000].size
# Out:
# 4

# %%
#find number of ducks
series[series==0]
# Out:
# Series([], Name: Price_USD, dtype: int64)

# %%
df = pd.read_csv("movies.txt",index_col='Movie_Title')
# Convert to Series
movies = df['Lead_Actor']
print(type(movies))
print(movies)
# Out:
# <class 'pandas.core.series.Series'>
# Movie_Title
# Avengers: Doomsday                               Robert Downey Jr.
# Oppenheimer                                      Robert Downey Jr.
# Sherlock Holmes 3                                Robert Downey Jr.
# Mission: Impossible - Dead Reckoning                    Tom Cruise
# Top Gun: Maverick                                       Tom Cruise
# Edge of Tomorrow                                        Tom Cruise
# Barbie                                               Margot Robbie
# A Big Bold Beautiful Journey                         Margot Robbie
# Suicide Squad                                        Margot Robbie
# Dune: Part Two                                             Zendaya
# Challengers                                                Zendaya
# Spider-Man: No Way Home                             Isabela Merced
# The Fall Guy                                          Ryan Gosling
# ...

# %%
#counts movies of each actor
num_movies=movies.value_counts()
num_movies>2
num_movies[num_movies>2]
# Out:
# Lead_Actor
# Isabela Merced        4
# Robert Downey Jr.     3
# Margot Robbie         3
# Tom Cruise            3
# Scarlett Johansson    3
# Ryan Gosling          3
# Name: count, dtype: int64
