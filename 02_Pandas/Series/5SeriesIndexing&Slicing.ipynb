# %%
import pandas as pd
import numpy as np

# %%
x=pd.Series([12,67,45,39,90,28])

# %%
#integer indexing ---positive indexing
print(x[2])
# Out:
# 45

# %%
cars = pd.read_csv("sample.txt",index_col='Car_Model')
# Convert to Series
series = cars.stack()
print(type(series))
print(series)
# Out:
# <class 'pandas.core.series.Series'>
# Car_Model
# Toyota Camry           Price_USD    26420
# Honda Civic            Price_USD    23950
# Ford Mustang           Price_USD    30920
# Tesla Model 3          Price_USD    38990
# Chevrolet Corvette     Price_USD    68300
# BMW M3                 Price_USD    76000
# Audi A4                Price_USD    41900
# Mercedes-Benz C-Class  Price_USD    46950
# Hyundai Elantra        Price_USD    21475
# Nissan Altima          Price_USD    25730
# dtype: int64

# %%
#negative indexing dosent work when index is number but when index is string it works
series[-1]
# Out:
# C:\Users\SUBODH\AppData\Local\Temp\ipykernel_20116\4130027189.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   series[-1]
# np.int64(25730)

# %%
print(series[0])
print(series['Honda Civic'])
# Out:
# 26420
# Price_USD    23950
# dtype: int64
# C:\Users\SUBODH\AppData\Local\Temp\ipykernel_20116\7196172.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(series[0])

# %%
#slicing
print(series[5:])
print(series[5:7])
# Out:
# Car_Model
# BMW M3                 Price_USD    76000
# Audi A4                Price_USD    41900
# Mercedes-Benz C-Class  Price_USD    46950
# Hyundai Elantra        Price_USD    21475
# Nissan Altima          Price_USD    25730
# dtype: int64
# Car_Model
# BMW M3     Price_USD    76000
# Audi A4    Price_USD    41900
# dtype: int64

# %%
#negative slicing
print(series[-5:])
# Out:
# Car_Model
# BMW M3                 Price_USD    76000
# Audi A4                Price_USD    41900
# Mercedes-Benz C-Class  Price_USD    46950
# Hyundai Elantra        Price_USD    21475
# Nissan Altima          Price_USD    25730
# dtype: int64

# %%
print(x[-5:])
# Out:
# 1    67
# 2    45
# 3    39
# 4    90
# 5    28
# dtype: int64

# %%
#fancy indexing
print(series[[1]])
# Out:
# Car_Model
# Honda Civic  Price_USD    23950
# dtype: int64
# C:\Users\SUBODH\AppData\Local\Temp\ipykernel_20116\4019005573.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(series[[1]])

# %%
#indexing with labels -> fancy indexing
print(series['Hyundai Elantra'])
# Out:
# Price_USD    21475
# dtype: int64
